# %% [markdown]
# # 🧠 MAESTRO Project Launcher
# Run this notebook to set up the environment and train the models automatically.

# %%
# 1. AUTO-DETECT & MOUNT DRIVE
import os
import sys

# Check if running on Colab
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    
    # SMART FINDER: Search for the folder containing 'dataset.py'
    print("🔍 Searching for project folder in Drive...")
    project_path = None
    for root, dirs, files in os.walk("/content/drive/MyDrive"):
        if "dataset.py" in files and "train.py" in files:
            project_path = root
            break
            
    if project_path:
        print(f"✅ Found project at: {project_path}")
        os.chdir(project_path) # Enter the folder
    else:
        print("❌ ERROR: Could not find 'dataset.py' in Google Drive.")
        print("   Please ensure you uploaded the repository folder to your Drive.")
else:
    print("✅ Running Locally (Not Colab).")

# %%
# 2. INSTALL DEPENDENCIES
# !pip install -r requirements.txt

# %%
# 3. RUN TRAINING
# !python train.py
